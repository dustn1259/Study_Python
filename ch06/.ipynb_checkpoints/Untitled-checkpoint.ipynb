# %%
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for key in params.keys():
            params[key]-=self.lr*grads[key]

# %%
class Momentum:
    def __init__(self, lr = 0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v= None
    
    def update(self,params,grads):
        if self.v is None:
            self.v = {}
            for key,val in params.items():
                self.v[key] = np.zeor_like(val)
                    
                    
        for key in params.key():
            self.v[key]=self.momentum*self.v[key]-self.lr*grads[key]
            params[key] += self.v[key]

# %%
class AdaGrad:
    def __init__(self, lr= 0.01):
        self.lr = lr
        self.h = None
        
    def update(self,params,grads):
        if self.h is None:
            self.h = {}
            for key, val in params.items():
                self.h[key] = np.zeros_like(val)
                
        for key in params.keys():
            self.h[key] += grads[key]*grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key])+1e-7)

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
from ch06.optimizer import *


def f(x, y):
    return x**2 / 20.0 + y**2


def df(x, y):
    return x / 10.0, 2.0*y

init_pos = (-7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0


optimizers = OrderedDict()
optimizers["SGD"] = SGD(lr=0.95)
optimizers["Momentum"] = Momentum(lr=0.1)
optimizers["AdaGrad"] = AdaGrad(lr=1.5)
optimizers["Adam"] = Adam(lr=0.3)

idx = 1

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]
    
    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])
        
        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)
    

    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)
    
    X, Y = np.meshgrid(x, y) 
    Z = f(X, Y)
    
    # 외곽선 단순화
    mask = Z > 7
    Z[mask] = 0
    
    # 그래프 그리기
    plt.subplot(2, 2, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim(-10, 10)
    plt.plot(0, 0, '+')
    #colorbar()
    #spring()
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")
    
plt.show()

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import matplotlib.pyplot as plt
from ch06.mnist import load_mnist
from ch06.util import smooth_curve
from ch06.multi_layer_net import MultiLayerNet
from ch06.optimizer import *


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
optimizers = {}
optimizers['SGD'] = SGD()
optimizers['Momentum'] = Momentum()
optimizers['AdaGrad'] = AdaGrad()
optimizers['Adam'] = Adam()
#optimizers['RMSprop'] = RMSprop()

networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []    


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D"}
x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# Downloading train-images-idx3-ubyte.gz ...
# Done
# Downloading train-labels-idx1-ubyte.gz ...
# Done
# Downloading t10k-images-idx3-ubyte.gz ...
# Done
# Downloading t10k-labels-idx1-ubyte.gz ...
# Done
# Converting train-images-idx3-ubyte.gz to NumPy Array ...
# Done
# Converting train-labels-idx1-ubyte.gz to NumPy Array ...
# Done
# Converting t10k-images-idx3-ubyte.gz to NumPy Array ...
# Done
# Converting t10k-labels-idx1-ubyte.gz to NumPy Array ...
# Done
# Creating pickle file ...
# Done!
# ===========iteration:0===========
# SGD:2.4002072090591575
# Momentum:2.387046647138093
# AdaGrad:2.0647132663160086
# Adam:2.2099111278130827
# ===========iteration:100===========
# SGD:1.5471967803928948
# Momentum:0.48087866959190906
# AdaGrad:0.2131569569038551
# Adam:0.29213947782913435
# ===========iteration:200===========
# SGD:0.7199524304334528
# Momentum:0.25530917044788987
# AdaGrad:0.11929999084631526
# Adam:0.16509539811949203
# ===========iteration:300===========
# SGD:0.5311540353289077
# Momentum:0.24115497639521846
# AdaGrad:0.1012552448819632
# Adam:0.21887950084530397
# ===========iteration:400===========
# SGD:0.4024418927259374
# Momentum:0.1604297053707742
# AdaGrad:0.08642375440875114
# Adam:0.10447083461511186
# ===========iteration:500===========
# SGD:0.3608378709603185
# Momentum:0.12927799728542141
# AdaGrad:0.04695025697886333
# Adam:0.10635239035376985
# ===========iteration:600===========
# SGD:0.34377075811273217
# Momentum:0.13957593760208098
# AdaGrad:0.06751050767524126
# Adam:0.07038472709931899
# ===========iteration:700===========
# SGD:0.24582459266169823
# Momentum:0.11284603927857607
# AdaGrad:0.039627250640294355
# Adam:0.06041828801900147
# ===========iteration:800===========
# SGD:0.20706655525372097
# Momentum:0.09593950228547143
# AdaGrad:0.027689755732022158
# Adam:0.0346723708781103
# ===========iteration:900===========
# SGD:0.2751989233748024
# Momentum:0.12962852925297821
# AdaGrad:0.039509512227887934
# Adam:0.08351708383157665
# ===========iteration:1000===========
# SGD:0.17196458179372132
# Momentum:0.04995908060850024
# AdaGrad:0.030856554171098265
# Adam:0.025795377676920528
# ===========iteration:1100===========
# SGD:0.25886736057604454
# Momentum:0.07769860826401633
# AdaGrad:0.055458020259138444
# Adam:0.046730995351607324
# ===========iteration:1200===========
# SGD:0.26463885696780093
# Momentum:0.04657275881729752
# AdaGrad:0.048182458074398575
# Adam:0.045662732083847093
# ===========iteration:1300===========
# SGD:0.20891592081271101
# Momentum:0.05545497632945867
# AdaGrad:0.03099785982293705
# Adam:0.04780094626025172
# ===========iteration:1400===========
# SGD:0.24474412737072399
# Momentum:0.07751229502873372
# AdaGrad:0.033779557330457045
# Adam:0.03770203831442459
# ===========iteration:1500===========
# SGD:0.23711983359720973
# Momentum:0.05536994594587066
# AdaGrad:0.04282270283852299
# Adam:0.024497511741955223
# ===========iteration:1600===========
# SGD:0.22944177584070288
# Momentum:0.11160400509034193
# AdaGrad:0.04908740520323905
# Adam:0.05272340988174213
# ===========iteration:1700===========
# SGD:0.2882537028323349
# Momentum:0.07147422612433317
# AdaGrad:0.07745472192669842
# Adam:0.04783767393441281
# ===========iteration:1800===========
# SGD:0.18029716075453453
# Momentum:0.054717710895368164
# AdaGrad:0.026727405246021657
# Adam:0.04502690037595471
# ===========iteration:1900===========
# SGD:0.30704192247054707
# Momentum:0.0777937322865008
# AdaGrad:0.07699428974446813
# Adam:0.042067582586528235

# %%
import numpy as ns
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-1))

x = np.random.randn(1000,100) #1000개의 데이터
node_num = 100 #각 은닉층의 노드(뉴런)수
w = np.random.randn(node_num, node_num)
hidden_layer_size= 5
activations = {}


for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
        
    w = np.random.randn(node_num, node_num) * 0.01
    a = np.dot(x,w)
    z = sigmoid(x)
    activations[i] = z
    
#히스토그램그리기
for i, a in activations.items():
    plt.subplot(1,len(activations),i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(),30,range=(0,1))
plt.show()

# %%
import numpy as ns
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-1))

x = np.random.randn(1000,100) #1000개의 데이터
node_num = 100 #앞 층의 노드 수
w = np.random.randn(node_num, node_num) / np.sqrt(node_num)
hidden_layer_size= 5
activations = {}


for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
        
    w = np.random.randn(node_num, node_num) * 0.01
    a = np.dot(x,w)
    z = sigmoid(x)
    activations[i] = z
    
#히스토그램그리기
for i, a in activations.items():
    plt.subplot(1,len(activations),i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(),30,range=(0,1))
plt.show()

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from ch06.mnist import load_mnist
from ch06.util import smooth_curve
from ch06.multi_layer_net import MultiLayerNet
from ch06.optimizer import SGD


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {'std=0.01': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# std=0.01:2.302489975724386
# Xavier:2.310383869958758
# He:2.3865826319821783
# ===========iteration:100===========
# std=0.01:2.301872584573384
# Xavier:2.2639941935358125
# He:1.701508710314835
# ===========iteration:200===========
# std=0.01:2.3021932673737506
# Xavier:2.1040118374896446
# He:0.709412699559302
# ===========iteration:300===========
# std=0.01:2.3016219004883043
# Xavier:1.8171910362598955
# He:0.5226375438620885
# ===========iteration:400===========
# std=0.01:2.3031563283517444
# Xavier:1.4349789275111613
# He:0.5700853176060892
# ===========iteration:500===========
# std=0.01:2.306068457269074
# Xavier:0.886134297335579
# He:0.40962301455180783
# ===========iteration:600===========
# std=0.01:2.299337688282445
# Xavier:0.6607434299501181
# He:0.31034766740405356
# ===========iteration:700===========
# std=0.01:2.2984872527172624
# Xavier:0.6569241734324678
# He:0.36744805890500587
# ===========iteration:800===========
# std=0.01:2.2976034108834216
# Xavier:0.5011364707304125
# He:0.2685251633902238
# ===========iteration:900===========
# std=0.01:2.3031578957156134
# Xavier:0.46580789655392796
# He:0.2729572413442701
# ===========iteration:1000===========
# std=0.01:2.300953270776999
# Xavier:0.46491624579765795
# He:0.26059827394508106
# ===========iteration:1100===========
# std=0.01:2.3023068918206144
# Xavier:0.4208431800801916
# He:0.2876996206169265
# ===========iteration:1200===========
# std=0.01:2.3001054331287394
# Xavier:0.4029998007316128
# He:0.29372319681720604
# ===========iteration:1300===========
# std=0.01:2.301984974173153
# Xavier:0.45046343431923436
# He:0.28388191218934533
# ===========iteration:1400===========
# std=0.01:2.306975109177587
# Xavier:0.4445937632782204
# He:0.31059530209108055
# ===========iteration:1500===========
# std=0.01:2.2953670312720282
# Xavier:0.497717395528272
# He:0.38252817420368435
# ===========iteration:1600===========
# std=0.01:2.294379171348808
# Xavier:0.4319837210869609
# He:0.30917085080197826
# ===========iteration:1700===========
# std=0.01:2.301187830654062
# Xavier:0.361047794582947
# He:0.26280430398648613
# ===========iteration:1800===========
# std=0.01:2.3085299430014574
# Xavier:0.43846256350639473
# He:0.29160845175041916
# ===========iteration:1900===========
# std=0.01:2.299544536538436
# Xavier:0.2591967466588382
# He:0.17172799559227592

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from ch06.mnist import load_mnist
from ch06.multi_layer_net_extend import MultiLayerNetExtend
from ch06.optimizer import SGD, Adam

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 학습 데이터를 줄임
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01


def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10, 
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
    
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
    
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
    
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
    
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list


# 그래프 그리기==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
    
    plt.subplot(4,4,i+1)
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')
    
plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.097 - 0.127
# ../ch06/multi_layer_net_extend.py:104: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# ../ch06/multi_layer_net_extend.py:104: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# epoch:1 | 0.097 - 0.157
# epoch:2 | 0.097 - 0.171
# epoch:3 | 0.097 - 0.194
# epoch:4 | 0.097 - 0.209
# epoch:5 | 0.097 - 0.219
# epoch:6 | 0.097 - 0.249
# epoch:7 | 0.097 - 0.252
# epoch:8 | 0.097 - 0.274
# epoch:9 | 0.097 - 0.288
# epoch:10 | 0.097 - 0.306
# epoch:11 | 0.097 - 0.325
# epoch:12 | 0.097 - 0.328
# epoch:13 | 0.097 - 0.351
# epoch:14 | 0.097 - 0.367
# epoch:15 | 0.097 - 0.388
# epoch:16 | 0.097 - 0.396
# epoch:17 | 0.097 - 0.405
# epoch:18 | 0.097 - 0.427
# No handles with labels found to put in legend.
# epoch:19 | 0.097 - 0.429
# ============== 2/16 ==============
# epoch:0 | 0.093 - 0.101
# ../ch06/multi_layer_net_extend.py:104: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# ../ch06/multi_layer_net_extend.py:104: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# epoch:1 | 0.097 - 0.096
# epoch:2 | 0.097 - 0.134
# epoch:3 | 0.097 - 0.174
# epoch:4 | 0.097 - 0.201
# epoch:5 | 0.097 - 0.22
# epoch:6 | 0.097 - 0.246
# epoch:7 | 0.097 - 0.27
# epoch:8 | 0.097 - 0.301
# epoch:9 | 0.097 - 0.319
# epoch:10 | 0.097 - 0.338
# epoch:11 | 0.097 - 0.366
# epoch:12 | 0.097 - 0.387
# epoch:13 | 0.097 - 0.407
# epoch:14 | 0.097 - 0.424
# epoch:15 | 0.097 - 0.45
# epoch:16 | 0.097 - 0.471
# epoch:17 | 0.097 - 0.477
# epoch:18 | 0.097 - 0.497
# No handles with labels found to put in legend.
# epoch:19 | 0.097 - 0.521
# ============== 3/16 ==============
# epoch:0 | 0.182 - 0.118
# epoch:1 | 0.372 - 0.11
# epoch:2 | 0.511 - 0.151
# epoch:3 | 0.575 - 0.183
# epoch:4 | 0.66 - 0.235
# epoch:5 | 0.733 - 0.272
# epoch:6 | 0.755 - 0.304
# epoch:7 | 0.796 - 0.337
# epoch:8 | 0.831 - 0.362
# epoch:9 | 0.859 - 0.398
# epoch:10 | 0.874 - 0.44
# epoch:11 | 0.909 - 0.466
# epoch:12 | 0.908 - 0.491
# epoch:13 | 0.926 - 0.538
# epoch:14 | 0.942 - 0.553
# epoch:15 | 0.953 - 0.59
# epoch:16 | 0.961 - 0.607
# epoch:17 | 0.974 - 0.62
# epoch:18 | 0.976 - 0.644
# No handles with labels found to put in legend.
# epoch:19 | 0.969 - 0.663
# ============== 4/16 ==============
# epoch:0 | 0.182 - 0.09
# epoch:1 | 0.304 - 0.128
# epoch:2 | 0.444 - 0.181
# epoch:3 | 0.547 - 0.267
# epoch:4 | 0.612 - 0.337
# epoch:5 | 0.654 - 0.382
# epoch:6 | 0.702 - 0.438
# epoch:7 | 0.726 - 0.495
# epoch:8 | 0.742 - 0.546
# epoch:9 | 0.764 - 0.579
# epoch:10 | 0.782 - 0.623
# epoch:11 | 0.798 - 0.645
# epoch:12 | 0.817 - 0.666
# epoch:13 | 0.826 - 0.7
# epoch:14 | 0.84 - 0.717
# epoch:15 | 0.843 - 0.732
# epoch:16 | 0.85 - 0.744
# epoch:17 | 0.856 - 0.76
# epoch:18 | 0.869 - 0.771
# No handles with labels found to put in legend.
# epoch:19 | 0.872 - 0.785
# ============== 5/16 ==============
# epoch:0 | 0.083 - 0.095
# epoch:1 | 0.095 - 0.151
# epoch:2 | 0.108 - 0.284
# epoch:3 | 0.115 - 0.454
# epoch:4 | 0.124 - 0.54
# epoch:5 | 0.133 - 0.598
# epoch:6 | 0.143 - 0.64
# epoch:7 | 0.149 - 0.682
# epoch:8 | 0.159 - 0.711
# epoch:9 | 0.16 - 0.736
# epoch:10 | 0.174 - 0.762
# epoch:11 | 0.172 - 0.779
# epoch:12 | 0.177 - 0.798
# epoch:13 | 0.193 - 0.814
# epoch:14 | 0.194 - 0.827
# epoch:15 | 0.195 - 0.835
# epoch:16 | 0.205 - 0.851
# epoch:17 | 0.206 - 0.856
# epoch:18 | 0.209 - 0.872
# No handles with labels found to put in legend.
# epoch:19 | 0.225 - 0.876
# ============== 6/16 ==============
# epoch:0 | 0.082 - 0.085
# epoch:1 | 0.096 - 0.173
# epoch:2 | 0.102 - 0.432
# epoch:3 | 0.12 - 0.6
# epoch:4 | 0.118 - 0.691
# epoch:5 | 0.123 - 0.743
# epoch:6 | 0.125 - 0.777
# epoch:7 | 0.117 - 0.818
# epoch:8 | 0.117 - 0.844
# epoch:9 | 0.117 - 0.862
# epoch:10 | 0.118 - 0.884
# epoch:11 | 0.155 - 0.9
# epoch:12 | 0.12 - 0.911
# epoch:13 | 0.141 - 0.921
# epoch:14 | 0.121 - 0.932
# epoch:15 | 0.164 - 0.938
# epoch:16 | 0.188 - 0.947
# epoch:17 | 0.182 - 0.951
# epoch:18 | 0.181 - 0.958
# No handles with labels found to put in legend.
# epoch:19 | 0.123 - 0.963
# ============== 7/16 ==============
# epoch:0 | 0.098 - 0.176
# epoch:1 | 0.116 - 0.316
# epoch:2 | 0.117 - 0.546
# epoch:3 | 0.117 - 0.685
# epoch:4 | 0.117 - 0.742
# epoch:5 | 0.117 - 0.793
# epoch:6 | 0.117 - 0.814
# epoch:7 | 0.117 - 0.85
# epoch:8 | 0.117 - 0.873
# epoch:9 | 0.117 - 0.9
# epoch:10 | 0.117 - 0.924
# epoch:11 | 0.117 - 0.947
# epoch:12 | 0.117 - 0.954
# epoch:13 | 0.117 - 0.965
# epoch:14 | 0.117 - 0.967
# epoch:15 | 0.117 - 0.974
# epoch:16 | 0.117 - 0.981
# epoch:17 | 0.117 - 0.985
# No handles with labels found to put in legend.
# epoch:18 | 0.117 - 0.987
# epoch:19 | 0.117 - 0.99
# ============== 8/16 ==============
# epoch:0 | 0.117 - 0.11
# epoch:1 | 0.1 - 0.415
# epoch:2 | 0.117 - 0.633
# epoch:3 | 0.117 - 0.757
# epoch:4 | 0.117 - 0.793
# epoch:5 | 0.117 - 0.835
# epoch:6 | 0.117 - 0.858
# epoch:7 | 0.117 - 0.881
# epoch:8 | 0.117 - 0.901
# epoch:9 | 0.117 - 0.93
# epoch:10 | 0.117 - 0.957
# epoch:11 | 0.117 - 0.979
# epoch:12 | 0.117 - 0.988
# epoch:13 | 0.117 - 0.993
# epoch:14 | 0.117 - 0.995
# epoch:15 | 0.117 - 0.995
# epoch:16 | 0.117 - 0.998
# epoch:17 | 0.117 - 0.998
# No handles with labels found to put in legend.
# epoch:18 | 0.117 - 1.0
# epoch:19 | 0.117 - 1.0
# ============== 9/16 ==============
# epoch:0 | 0.105 - 0.091
# epoch:1 | 0.117 - 0.519
# epoch:2 | 0.117 - 0.767
# epoch:3 | 0.117 - 0.827
# epoch:4 | 0.117 - 0.872
# epoch:5 | 0.117 - 0.917
# epoch:6 | 0.116 - 0.965
# epoch:7 | 0.116 - 0.98
# epoch:8 | 0.116 - 0.99
# epoch:9 | 0.116 - 0.992
# epoch:10 | 0.116 - 0.993
# epoch:11 | 0.116 - 1.0
# epoch:12 | 0.116 - 1.0
# epoch:13 | 0.117 - 1.0
# epoch:14 | 0.117 - 1.0
# epoch:15 | 0.117 - 1.0
# epoch:16 | 0.116 - 1.0
# epoch:17 | 0.116 - 1.0
# No handles with labels found to put in legend.
# epoch:18 | 0.116 - 1.0
# epoch:19 | 0.116 - 1.0
# ============== 10/16 ==============
# epoch:0 | 0.099 - 0.129
# epoch:1 | 0.117 - 0.493
# epoch:2 | 0.117 - 0.757
# epoch:3 | 0.117 - 0.795
# epoch:4 | 0.116 - 0.811
# epoch:5 | 0.116 - 0.876
# epoch:6 | 0.117 - 0.859
# epoch:7 | 0.116 - 0.851
# epoch:8 | 0.117 - 0.885
# epoch:9 | 0.117 - 0.902
# epoch:10 | 0.117 - 0.958
# epoch:11 | 0.117 - 0.991
# epoch:12 | 0.116 - 0.994
# epoch:13 | 0.117 - 0.997
# epoch:14 | 0.117 - 0.997
# epoch:15 | 0.117 - 0.997
# epoch:16 | 0.117 - 0.999
# epoch:17 | 0.117 - 0.983
# No handles with labels found to put in legend.
# epoch:18 | 0.117 - 0.99
# epoch:19 | 0.117 - 0.995
# ============== 11/16 ==============
# epoch:0 | 0.097 - 0.097
# epoch:1 | 0.117 - 0.716
# epoch:2 | 0.117 - 0.78
# epoch:3 | 0.117 - 0.822
# epoch:4 | 0.117 - 0.813
# epoch:5 | 0.117 - 0.825
# epoch:6 | 0.117 - 0.863
# epoch:7 | 0.117 - 0.738
# epoch:8 | 0.117 - 0.875
# epoch:9 | 0.117 - 0.89
# epoch:10 | 0.117 - 0.894
# epoch:11 | 0.117 - 0.902
# epoch:12 | 0.117 - 0.899
# epoch:13 | 0.117 - 0.9
# epoch:14 | 0.117 - 0.9
# epoch:15 | 0.117 - 0.9
# epoch:16 | 0.117 - 0.898
# epoch:17 | 0.117 - 0.899
# No handles with labels found to put in legend.
# epoch:18 | 0.117 - 0.9
# epoch:19 | 0.117 - 0.902
# ============== 12/16 ==============
# epoch:0 | 0.117 - 0.14
# epoch:1 | 0.117 - 0.413
# epoch:2 | 0.116 - 0.323
# epoch:3 | 0.116 - 0.648
# epoch:4 | 0.116 - 0.575
# epoch:5 | 0.116 - 0.723
# epoch:6 | 0.116 - 0.753
# epoch:7 | 0.116 - 0.851
# epoch:8 | 0.117 - 0.867
# epoch:9 | 0.117 - 0.855
# epoch:10 | 0.117 - 0.881
# epoch:11 | 0.116 - 0.877
# epoch:12 | 0.116 - 0.887
# epoch:13 | 0.116 - 0.889
# epoch:14 | 0.116 - 0.89
# epoch:15 | 0.116 - 0.891
# epoch:16 | 0.117 - 0.894
# epoch:17 | 0.117 - 0.884
# No handles with labels found to put in legend.
# epoch:18 | 0.116 - 0.897
# epoch:19 | 0.117 - 0.897
# ============== 13/16 ==============
# epoch:0 | 0.117 - 0.118
# epoch:1 | 0.116 - 0.49
# epoch:2 | 0.116 - 0.535
# epoch:3 | 0.116 - 0.646
# epoch:4 | 0.116 - 0.655
# epoch:5 | 0.116 - 0.664
# epoch:6 | 0.116 - 0.682
# epoch:7 | 0.116 - 0.685
# epoch:8 | 0.116 - 0.684
# epoch:9 | 0.116 - 0.684
# epoch:10 | 0.116 - 0.694
# epoch:11 | 0.116 - 0.698
# epoch:12 | 0.116 - 0.703
# epoch:13 | 0.116 - 0.7
# epoch:14 | 0.116 - 0.709
# epoch:15 | 0.116 - 0.715
# epoch:16 | 0.116 - 0.713
# epoch:17 | 0.116 - 0.715
# No handles with labels found to put in legend.
# epoch:18 | 0.116 - 0.713
# epoch:19 | 0.116 - 0.721
# ============== 14/16 ==============
# epoch:0 | 0.1 - 0.129
# epoch:1 | 0.117 - 0.34
# epoch:2 | 0.117 - 0.45
# epoch:3 | 0.117 - 0.564
# epoch:4 | 0.117 - 0.567
# epoch:5 | 0.117 - 0.589
# epoch:6 | 0.117 - 0.501
# epoch:7 | 0.117 - 0.594
# epoch:8 | 0.117 - 0.549
# epoch:9 | 0.117 - 0.611
# epoch:10 | 0.117 - 0.684
# epoch:11 | 0.117 - 0.705
# epoch:12 | 0.117 - 0.711
# epoch:13 | 0.117 - 0.71
# epoch:14 | 0.117 - 0.704
# epoch:15 | 0.117 - 0.712
# epoch:16 | 0.117 - 0.716
# epoch:17 | 0.117 - 0.717
# No handles with labels found to put in legend.
# epoch:18 | 0.117 - 0.717
# epoch:19 | 0.117 - 0.705
# ============== 15/16 ==============
# epoch:0 | 0.116 - 0.097
# epoch:1 | 0.117 - 0.359
# epoch:2 | 0.117 - 0.461
# epoch:3 | 0.116 - 0.478
# epoch:4 | 0.117 - 0.494
# epoch:5 | 0.117 - 0.501
# epoch:6 | 0.117 - 0.495
# epoch:7 | 0.116 - 0.511
# epoch:8 | 0.116 - 0.501
# epoch:9 | 0.116 - 0.51
# epoch:10 | 0.116 - 0.515
# epoch:11 | 0.116 - 0.517
# epoch:12 | 0.116 - 0.52
# epoch:13 | 0.116 - 0.522
# epoch:14 | 0.116 - 0.523
# epoch:15 | 0.116 - 0.519
# epoch:16 | 0.116 - 0.522
# epoch:17 | 0.116 - 0.525
# No handles with labels found to put in legend.
# epoch:18 | 0.116 - 0.523
# epoch:19 | 0.116 - 0.525
# ============== 16/16 ==============
# epoch:0 | 0.117 - 0.133
# epoch:1 | 0.116 - 0.139
# epoch:2 | 0.116 - 0.31
# epoch:3 | 0.116 - 0.315
# epoch:4 | 0.116 - 0.318
# epoch:5 | 0.116 - 0.321
# epoch:6 | 0.116 - 0.322
# epoch:7 | 0.116 - 0.326
# epoch:8 | 0.116 - 0.324
# epoch:9 | 0.116 - 0.326
# epoch:10 | 0.116 - 0.386
# epoch:11 | 0.116 - 0.407
# epoch:12 | 0.116 - 0.412
# epoch:13 | 0.116 - 0.421
# epoch:14 | 0.116 - 0.42
# epoch:15 | 0.116 - 0.423
# epoch:16 | 0.116 - 0.412
# epoch:17 | 0.116 - 0.421
# epoch:18 | 0.117 - 0.422
# epoch:19 | 0.117 - 0.421

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from ch06.mnist import load_mnist
from ch06.multi_layer_net import MultiLayerNet
from ch06.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.11666666666666667, test acc:0.1024
# epoch:1, train acc:0.13333333333333333, test acc:0.1047
# epoch:2, train acc:0.16333333333333333, test acc:0.1104
# epoch:3, train acc:0.19, test acc:0.1282
# epoch:4, train acc:0.24666666666666667, test acc:0.15
# epoch:5, train acc:0.28, test acc:0.172
# epoch:6, train acc:0.31, test acc:0.1974
# epoch:7, train acc:0.3233333333333333, test acc:0.2154
# epoch:8, train acc:0.3433333333333333, test acc:0.2479
# epoch:9, train acc:0.37, test acc:0.2605
# epoch:10, train acc:0.37666666666666665, test acc:0.2857
# epoch:11, train acc:0.4166666666666667, test acc:0.3055
# epoch:12, train acc:0.44666666666666666, test acc:0.3271
# epoch:13, train acc:0.45, test acc:0.3331
# epoch:14, train acc:0.4666666666666667, test acc:0.3417
# epoch:15, train acc:0.47, test acc:0.3338
# epoch:16, train acc:0.48333333333333334, test acc:0.338
# epoch:17, train acc:0.4666666666666667, test acc:0.3533
# epoch:18, train acc:0.5, test acc:0.3811
# epoch:19, train acc:0.5233333333333333, test acc:0.3898
# epoch:20, train acc:0.52, test acc:0.3999
# epoch:21, train acc:0.5333333333333333, test acc:0.4102
# epoch:22, train acc:0.5566666666666666, test acc:0.4192
# epoch:23, train acc:0.56, test acc:0.4161
# epoch:24, train acc:0.58, test acc:0.4409
# epoch:25, train acc:0.5866666666666667, test acc:0.4528
# epoch:26, train acc:0.5866666666666667, test acc:0.449
# epoch:27, train acc:0.5733333333333334, test acc:0.4377
# epoch:28, train acc:0.5966666666666667, test acc:0.4626
# epoch:29, train acc:0.6233333333333333, test acc:0.4758
# epoch:30, train acc:0.64, test acc:0.4744
# epoch:31, train acc:0.6333333333333333, test acc:0.4747
# epoch:32, train acc:0.6333333333333333, test acc:0.4868
# epoch:33, train acc:0.6466666666666666, test acc:0.4898
# epoch:34, train acc:0.6566666666666666, test acc:0.505
# epoch:35, train acc:0.6433333333333333, test acc:0.5162
# epoch:36, train acc:0.68, test acc:0.5257
# epoch:37, train acc:0.6766666666666666, test acc:0.5293
# epoch:38, train acc:0.6933333333333334, test acc:0.5358
# epoch:39, train acc:0.7066666666666667, test acc:0.5484
# epoch:40, train acc:0.6933333333333334, test acc:0.5401
# epoch:41, train acc:0.7133333333333334, test acc:0.5441
# epoch:42, train acc:0.7333333333333333, test acc:0.5628
# epoch:43, train acc:0.72, test acc:0.5616
# epoch:44, train acc:0.73, test acc:0.5575
# epoch:45, train acc:0.7266666666666667, test acc:0.5704
# epoch:46, train acc:0.7533333333333333, test acc:0.5863
# epoch:47, train acc:0.7733333333333333, test acc:0.5996
# epoch:48, train acc:0.7766666666666666, test acc:0.5941
# epoch:49, train acc:0.75, test acc:0.5924
# epoch:50, train acc:0.78, test acc:0.5933
# epoch:51, train acc:0.7633333333333333, test acc:0.5988
# epoch:52, train acc:0.79, test acc:0.6123
# epoch:53, train acc:0.7966666666666666, test acc:0.621
# epoch:54, train acc:0.7833333333333333, test acc:0.6204
# epoch:55, train acc:0.78, test acc:0.6233
# epoch:56, train acc:0.7933333333333333, test acc:0.6305
# epoch:57, train acc:0.8233333333333334, test acc:0.6295
# epoch:58, train acc:0.8233333333333334, test acc:0.6382
# epoch:59, train acc:0.8333333333333334, test acc:0.6552
# epoch:60, train acc:0.8233333333333334, test acc:0.6499
# epoch:61, train acc:0.8266666666666667, test acc:0.6596
# epoch:62, train acc:0.8266666666666667, test acc:0.662
# epoch:63, train acc:0.83, test acc:0.6641
# epoch:64, train acc:0.8433333333333334, test acc:0.6646
# epoch:65, train acc:0.8533333333333334, test acc:0.6703
# epoch:66, train acc:0.83, test acc:0.6592
# epoch:67, train acc:0.8566666666666667, test acc:0.6667
# epoch:68, train acc:0.86, test acc:0.6762
# epoch:69, train acc:0.87, test acc:0.69
# epoch:70, train acc:0.87, test acc:0.6899
# epoch:71, train acc:0.8666666666666667, test acc:0.6989
# epoch:72, train acc:0.86, test acc:0.694
# epoch:73, train acc:0.87, test acc:0.6932
# epoch:74, train acc:0.8866666666666667, test acc:0.6978
# epoch:75, train acc:0.8733333333333333, test acc:0.704
# epoch:76, train acc:0.89, test acc:0.7069
# epoch:77, train acc:0.8833333333333333, test acc:0.6998
# epoch:78, train acc:0.88, test acc:0.7103
# epoch:79, train acc:0.8766666666666667, test acc:0.7085
# epoch:80, train acc:0.88, test acc:0.7049
# epoch:81, train acc:0.8833333333333333, test acc:0.7084
# epoch:82, train acc:0.89, test acc:0.713
# epoch:83, train acc:0.8833333333333333, test acc:0.7208
# epoch:84, train acc:0.8933333333333333, test acc:0.7205
# epoch:85, train acc:0.89, test acc:0.7123
# epoch:86, train acc:0.8833333333333333, test acc:0.7041
# epoch:87, train acc:0.89, test acc:0.7123
# epoch:88, train acc:0.9, test acc:0.7224
# epoch:89, train acc:0.9, test acc:0.726
# epoch:90, train acc:0.8833333333333333, test acc:0.711
# epoch:91, train acc:0.89, test acc:0.7185
# epoch:92, train acc:0.8766666666666667, test acc:0.7003
# epoch:93, train acc:0.8966666666666666, test acc:0.7157
# epoch:94, train acc:0.8933333333333333, test acc:0.7113
# epoch:95, train acc:0.9033333333333333, test acc:0.7204
# epoch:96, train acc:0.9, test acc:0.7134
# epoch:97, train acc:0.9033333333333333, test acc:0.7197
# epoch:98, train acc:0.9, test acc:0.721
# epoch:99, train acc:0.9033333333333333, test acc:0.7237
# epoch:100, train acc:0.9066666666666666, test acc:0.7187
# epoch:101, train acc:0.9066666666666666, test acc:0.7254
# epoch:102, train acc:0.8966666666666666, test acc:0.7225
# epoch:103, train acc:0.9066666666666666, test acc:0.7192
# epoch:104, train acc:0.9033333333333333, test acc:0.7186
# epoch:105, train acc:0.9, test acc:0.7187
# epoch:106, train acc:0.9, test acc:0.724
# epoch:107, train acc:0.9066666666666666, test acc:0.7212
# epoch:108, train acc:0.91, test acc:0.7233
# epoch:109, train acc:0.9033333333333333, test acc:0.7252
# epoch:110, train acc:0.9166666666666666, test acc:0.7243
# epoch:111, train acc:0.9066666666666666, test acc:0.7256
# epoch:112, train acc:0.9, test acc:0.7223
# epoch:113, train acc:0.9066666666666666, test acc:0.7225
# epoch:114, train acc:0.9066666666666666, test acc:0.7147
# epoch:115, train acc:0.91, test acc:0.7192
# epoch:116, train acc:0.9166666666666666, test acc:0.7208
# epoch:117, train acc:0.9133333333333333, test acc:0.7207
# epoch:118, train acc:0.92, test acc:0.7288
# epoch:119, train acc:0.9066666666666666, test acc:0.7254
# epoch:120, train acc:0.9166666666666666, test acc:0.7252
# epoch:121, train acc:0.92, test acc:0.7236
# epoch:122, train acc:0.9133333333333333, test acc:0.7325
# epoch:123, train acc:0.9166666666666666, test acc:0.7347
# epoch:124, train acc:0.9133333333333333, test acc:0.7323
# epoch:125, train acc:0.9133333333333333, test acc:0.7351
# epoch:126, train acc:0.91, test acc:0.7342
# epoch:127, train acc:0.9066666666666666, test acc:0.7272
# epoch:128, train acc:0.9133333333333333, test acc:0.7311
# epoch:129, train acc:0.9233333333333333, test acc:0.7326
# epoch:130, train acc:0.92, test acc:0.7313
# epoch:131, train acc:0.9166666666666666, test acc:0.7337
# epoch:132, train acc:0.92, test acc:0.7332
# epoch:133, train acc:0.9233333333333333, test acc:0.7287
# epoch:134, train acc:0.9133333333333333, test acc:0.7313
# epoch:135, train acc:0.9233333333333333, test acc:0.7295
# epoch:136, train acc:0.9166666666666666, test acc:0.7291
# epoch:137, train acc:0.9233333333333333, test acc:0.7315
# epoch:138, train acc:0.9166666666666666, test acc:0.7284
# epoch:139, train acc:0.91, test acc:0.7339
# epoch:140, train acc:0.91, test acc:0.7319
# epoch:141, train acc:0.91, test acc:0.7379
# epoch:142, train acc:0.92, test acc:0.7321
# epoch:143, train acc:0.9266666666666666, test acc:0.7385
# epoch:144, train acc:0.9233333333333333, test acc:0.7344
# epoch:145, train acc:0.93, test acc:0.7347
# epoch:146, train acc:0.92, test acc:0.7335
# epoch:147, train acc:0.9266666666666666, test acc:0.7301
# epoch:148, train acc:0.9166666666666666, test acc:0.7387
# epoch:149, train acc:0.9166666666666666, test acc:0.7356
# epoch:150, train acc:0.9166666666666666, test acc:0.7373
# epoch:151, train acc:0.9333333333333333, test acc:0.7317
# epoch:152, train acc:0.9166666666666666, test acc:0.7386
# epoch:153, train acc:0.9166666666666666, test acc:0.7373
# epoch:154, train acc:0.9233333333333333, test acc:0.7254
# epoch:155, train acc:0.9166666666666666, test acc:0.7319
# epoch:156, train acc:0.9233333333333333, test acc:0.7331
# epoch:157, train acc:0.9333333333333333, test acc:0.737
# epoch:158, train acc:0.92, test acc:0.7371
# epoch:159, train acc:0.9166666666666666, test acc:0.7342
# epoch:160, train acc:0.93, test acc:0.7296
# epoch:161, train acc:0.93, test acc:0.7346
# epoch:162, train acc:0.92, test acc:0.7385
# epoch:163, train acc:0.92, test acc:0.7416
# epoch:164, train acc:0.94, test acc:0.7386
# epoch:165, train acc:0.92, test acc:0.7384
# epoch:166, train acc:0.9266666666666666, test acc:0.7326
# epoch:167, train acc:0.93, test acc:0.7338
# epoch:168, train acc:0.9166666666666666, test acc:0.7391
# epoch:169, train acc:0.93, test acc:0.741
# epoch:170, train acc:0.93, test acc:0.7313
# epoch:171, train acc:0.9333333333333333, test acc:0.7388
# epoch:172, train acc:0.9333333333333333, test acc:0.7422
# epoch:173, train acc:0.92, test acc:0.7365
# epoch:174, train acc:0.9366666666666666, test acc:0.7364
# epoch:175, train acc:0.93, test acc:0.7398
# epoch:176, train acc:0.93, test acc:0.7378
# epoch:177, train acc:0.9233333333333333, test acc:0.7412
# epoch:178, train acc:0.9266666666666666, test acc:0.7426
# epoch:179, train acc:0.9266666666666666, test acc:0.734
# epoch:180, train acc:0.92, test acc:0.73
# epoch:181, train acc:0.93, test acc:0.7395
# epoch:182, train acc:0.9233333333333333, test acc:0.7416
# epoch:183, train acc:0.9233333333333333, test acc:0.7352
# epoch:184, train acc:0.93, test acc:0.735
# epoch:185, train acc:0.9366666666666666, test acc:0.742
# epoch:186, train acc:0.9366666666666666, test acc:0.7434
# epoch:187, train acc:0.93, test acc:0.7339
# epoch:188, train acc:0.9366666666666666, test acc:0.742
# epoch:189, train acc:0.9333333333333333, test acc:0.7411
# epoch:190, train acc:0.9333333333333333, test acc:0.7351
# epoch:191, train acc:0.9333333333333333, test acc:0.7314
# epoch:192, train acc:0.93, test acc:0.733
# epoch:193, train acc:0.9333333333333333, test acc:0.725
# epoch:194, train acc:0.9333333333333333, test acc:0.7354
# epoch:195, train acc:0.9333333333333333, test acc:0.7364
# epoch:196, train acc:0.9266666666666666, test acc:0.7288
# epoch:197, train acc:0.93, test acc:0.7394
# epoch:198, train acc:0.9266666666666666, test acc:0.7341
# epoch:199, train acc:0.9433333333333334, test acc:0.7342
# epoch:200, train acc:0.9433333333333334, test acc:0.7336

# %%
#드롭아웃
class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None
        
    def forward(self,x,train_flg = True):
        if train_flg:
            self.mask = np.ranndom.randn(*x.shape) > self.dropout_ratio
            return x * self.mask
        else: 
            return x * (1.0-self.dropout_ratio)
        
    def backward(self,dout):
        return dout * self.mask

# %%
# coding: utf-8
import os
import sys
import numpy as np
sys.path.append(os.pardir)
from ch06.mnist import load_mnist
(x_train, t_train), (x_test, t_test) = load_mnist()

def shuffle_dataset(x, t):
    """데이터셋을 뒤섞는다.

    Parameters
    ----------
    x : 훈련 데이터
    t : 정답 레이블
    
    Returns
    -------
    x, t : 뒤섞은 훈련 데이터와 정답 레이블
    """
    permutation = np.random.permutation(x.shape[0])
    x = x[permutation,:] if x.ndim == 2 else x[permutation,:,:,:]
    t = t[permutation]

    return x, t

#훈련데이터를 뒤섞는다
x_train, t_train = shuffle_dataset(x_train,t_train)

#20%를 검증 데이터로 분할
validation_rate = 0.20
validation_num = int(x_train.shape[0]*validation_rate)

x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num]
t_train = t_train[validation_num]

# %%
weight_decay = 10 ** np.random.uniform(-8,-4)
lr = 10 ** np.random.uniform(-6,-2)

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from ch06.mnist import load_mnist
from ch06.multi_layer_net import MultiLayerNet
from ch06.util import shuffle_dataset
from ch06.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 결과를 빠르게 얻기 위해 훈련 데이터를 줄임
x_train = x_train[:500]
t_train = t_train[:500]

# 20%를 검증 데이터로 분할
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


# 하이퍼파라미터 무작위 탐색======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 탐색한 하이퍼파라미터의 범위 지정===============
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# 그래프 그리기========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# val acc:0.81 | lr:0.00809032080176138, weight decay:7.303903811719128e-07
# val acc:0.11 | lr:1.3048755736069478e-05, weight decay:1.2775916900893075e-05
# val acc:0.14 | lr:0.00024298302710805178, weight decay:1.5866016141345673e-05
# val acc:0.15 | lr:0.00022104672742935443, weight decay:8.232677992164055e-07
# val acc:0.14 | lr:9.586205972082666e-06, weight decay:3.1402831764633075e-08
# val acc:0.32 | lr:0.0019401186812738195, weight decay:1.0767856048009218e-08
# val acc:0.06 | lr:2.027516402938273e-06, weight decay:1.734501396562027e-06
# val acc:0.1 | lr:6.96348403388638e-05, weight decay:3.6724836231900623e-06
# val acc:0.15 | lr:1.989110457288076e-05, weight decay:2.6511121492483182e-05
# val acc:0.7 | lr:0.0056991788309099164, weight decay:1.5451461972951767e-05
# val acc:0.11 | lr:1.2942143725309182e-06, weight decay:1.0278595551989553e-08
# val acc:0.1 | lr:3.0248683414610535e-06, weight decay:6.55006748442119e-05
# val acc:0.16 | lr:0.0003836545108446229, weight decay:7.152352420971839e-06
# val acc:0.34 | lr:0.003000261343567309, weight decay:7.726689232090652e-07
# val acc:0.15 | lr:4.888100257341682e-05, weight decay:1.4585235659874073e-05
# val acc:0.08 | lr:1.0062009141050578e-05, weight decay:7.423367495237012e-07
# val acc:0.08 | lr:0.00022384015941548182, weight decay:1.3328209022172814e-08
# val acc:0.27 | lr:0.000637384191268236, weight decay:1.458050531833478e-08
# val acc:0.22 | lr:0.0011149867119866431, weight decay:4.3193305121781325e-08
# val acc:0.38 | lr:0.001676733428387392, weight decay:6.196202850187026e-08
# val acc:0.18 | lr:0.0003023593905027376, weight decay:5.167527023407475e-05
# val acc:0.11 | lr:0.0008558451124706775, weight decay:2.191465842722555e-07
# val acc:0.31 | lr:0.002586946908303264, weight decay:8.259712738528455e-05
# val acc:0.15 | lr:6.968239980845613e-05, weight decay:9.88009163707742e-08
# val acc:0.15 | lr:0.0002035608623875131, weight decay:3.986091191051599e-06
# val acc:0.13 | lr:0.00040935769448966717, weight decay:1.6786887003222616e-05
# val acc:0.06 | lr:1.4127771995207792e-06, weight decay:6.296758916322433e-06
# val acc:0.63 | lr:0.0031914676865903062, weight decay:8.06787530792735e-07
# val acc:0.21 | lr:0.000382030456564876, weight decay:5.193931227883122e-08
# val acc:0.1 | lr:0.00026708385549590534, weight decay:8.31034545204948e-06
# val acc:0.84 | lr:0.008645200221660845, weight decay:1.069388063387563e-06
# val acc:0.08 | lr:0.00018850122538536179, weight decay:2.1470448606625475e-06
# val acc:0.1 | lr:1.9426902105631935e-05, weight decay:2.6224954823411097e-06
# val acc:0.18 | lr:0.0027442638369111765, weight decay:2.3384453351606247e-08
# val acc:0.28 | lr:0.0013676246833997825, weight decay:6.636261820757041e-05
# val acc:0.09 | lr:0.0002541317307160194, weight decay:9.012905717389806e-06
# val acc:0.11 | lr:2.622168663425144e-06, weight decay:1.7142344754093698e-05
# val acc:0.13 | lr:0.00031327477804613766, weight decay:8.507743775599566e-06
# val acc:0.21 | lr:0.0020682352426803475, weight decay:3.3777062670274155e-07
# val acc:0.09 | lr:1.236388374324913e-05, weight decay:7.284098538702594e-06
# val acc:0.25 | lr:0.0007178349031767954, weight decay:6.537313406085892e-05
# val acc:0.07 | lr:1.6778420010539854e-05, weight decay:3.4529299812740624e-08
# val acc:0.58 | lr:0.004059449733380621, weight decay:8.226456102867736e-07
# val acc:0.06 | lr:0.00013788071010862742, weight decay:1.1603023903751681e-05
# val acc:0.16 | lr:0.00021413703674755377, weight decay:8.303778182529698e-05
# val acc:0.15 | lr:6.900850697439123e-06, weight decay:1.7709058318201743e-07
# val acc:0.08 | lr:1.3509484946115768e-06, weight decay:2.653796994384865e-08
# val acc:0.32 | lr:0.0010747572972545296, weight decay:1.8232479504070807e-08
# val acc:0.33 | lr:0.001525596258996269, weight decay:5.044617652141686e-08
# val acc:0.12 | lr:0.00015335919047088653, weight decay:8.896046176962047e-05
# val acc:0.6 | lr:0.004837987929554573, weight decay:1.3506634388304737e-08
# val acc:0.12 | lr:0.0008249975113389711, weight decay:3.30955393915103e-06
# val acc:0.39 | lr:0.002586797222672896, weight decay:1.2792490053807584e-07
# val acc:0.48 | lr:0.003978599291204263, weight decay:9.56907718686138e-08
# val acc:0.06 | lr:1.8211463509760037e-06, weight decay:1.4058418983891223e-05
# val acc:0.64 | lr:0.004402908919236055, weight decay:7.625617003695102e-07
# val acc:0.09 | lr:6.62450697006806e-06, weight decay:7.606804054490465e-06
# val acc:0.07 | lr:0.0002498134284515379, weight decay:1.7146087412950096e-07
# val acc:0.26 | lr:0.002235417494841485, weight decay:7.60155058104173e-05
# val acc:0.13 | lr:0.00010288807800861131, weight decay:4.030823283762801e-08
# val acc:0.04 | lr:0.0001776409416237447, weight decay:4.574558114660142e-06
# val acc:0.14 | lr:7.059378218870425e-06, weight decay:1.218071789872609e-08
# val acc:0.12 | lr:1.0235058688159269e-06, weight decay:5.575034849585805e-08
# val acc:0.1 | lr:3.5992057871421255e-06, weight decay:4.4132905698415236e-06
# val acc:0.15 | lr:5.2749922933936225e-05, weight decay:2.633106306314719e-06
# val acc:0.73 | lr:0.006375766322268736, weight decay:1.6189935794115073e-05
# val acc:0.11 | lr:5.519475899335271e-06, weight decay:8.947638509221869e-07
# val acc:0.12 | lr:2.7599839836637184e-06, weight decay:8.939905086787987e-07
# val acc:0.1 | lr:1.2815122181420682e-05, weight decay:6.928415125445496e-07
# val acc:0.07 | lr:5.850386538340694e-05, weight decay:4.115158884176541e-07
# val acc:0.14 | lr:0.00046665924859095654, weight decay:7.286545841486062e-05
# val acc:0.11 | lr:5.3245835106878606e-06, weight decay:1.3654742031843675e-08
# val acc:0.1 | lr:0.0003198707308500798, weight decay:6.672153733003538e-05
# val acc:0.08 | lr:1.0200158648593056e-05, weight decay:2.7456083319376825e-05
# val acc:0.08 | lr:4.713244972045332e-05, weight decay:3.4765081474701514e-05
# val acc:0.09 | lr:4.035908919329014e-06, weight decay:2.403490172386783e-08
# val acc:0.07 | lr:5.416274445434272e-05, weight decay:7.747307563925856e-06
# val acc:0.09 | lr:6.330116940781597e-06, weight decay:9.688809622055294e-08
# val acc:0.1 | lr:4.466785023425318e-05, weight decay:6.59922599872186e-07
# val acc:0.1 | lr:3.778783788519958e-05, weight decay:1.3744978237066286e-08
# val acc:0.09 | lr:0.000122296613649847, weight decay:7.303034650998683e-05
# val acc:0.07 | lr:2.70935086516599e-06, weight decay:4.985183350229806e-07
# val acc:0.12 | lr:0.00029760501205164413, weight decay:1.5863413101736165e-08
# val acc:0.25 | lr:0.001259885379413089, weight decay:3.9234606590293106e-08
# val acc:0.17 | lr:8.312387496482204e-05, weight decay:1.3024949279935965e-05
# val acc:0.09 | lr:1.025046601688684e-05, weight decay:4.226652679398558e-08
# val acc:0.04 | lr:0.0003876051924421537, weight decay:2.3561474888039563e-06
# val acc:0.1 | lr:9.069912677077188e-05, weight decay:3.373408523291953e-08
# val acc:0.08 | lr:1.5354373641240116e-05, weight decay:5.5026943414455685e-06
# val acc:0.12 | lr:2.4318510107945213e-05, weight decay:1.5706043125265852e-08
# val acc:0.12 | lr:1.959511150406657e-05, weight decay:3.52543843730073e-05
# val acc:0.08 | lr:0.00011629844946034919, weight decay:1.4019901755396662e-06
# val acc:0.42 | lr:0.0032980312862981678, weight decay:3.2525569674224774e-08
# val acc:0.26 | lr:0.0015841248880156574, weight decay:1.3564615149330525e-08
# val acc:0.15 | lr:0.0002909235166981661, weight decay:6.614962983500435e-07
# val acc:0.2 | lr:0.00010552476487286002, weight decay:9.287481610318955e-08
# val acc:0.16 | lr:3.0802778814613027e-06, weight decay:2.991326949684296e-06
# val acc:0.13 | lr:0.0004633007946988967, weight decay:1.608661394235535e-07
# val acc:0.09 | lr:6.246751230679286e-05, weight decay:2.019559838724856e-07
# val acc:0.2 | lr:2.3806025424925626e-06, weight decay:5.912787260418406e-07
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.84) | lr:0.008645200221660845, weight decay:1.069388063387563e-06
# Best-2(val acc:0.81) | lr:0.00809032080176138, weight decay:7.303903811719128e-07
# Best-3(val acc:0.73) | lr:0.006375766322268736, weight decay:1.6189935794115073e-05
# Best-4(val acc:0.7) | lr:0.0056991788309099164, weight decay:1.5451461972951767e-05
# Best-5(val acc:0.64) | lr:0.004402908919236055, weight decay:7.625617003695102e-07
# Best-6(val acc:0.63) | lr:0.0031914676865903062, weight decay:8.06787530792735e-07
# Best-7(val acc:0.6) | lr:0.004837987929554573, weight decay:1.3506634388304737e-08
# Best-8(val acc:0.58) | lr:0.004059449733380621, weight decay:8.226456102867736e-07
# Best-9(val acc:0.48) | lr:0.003978599291204263, weight decay:9.56907718686138e-08
# Best-10(val acc:0.42) | lr:0.0032980312862981678, weight decay:3.2525569674224774e-08
# Best-11(val acc:0.39) | lr:0.002586797222672896, weight decay:1.2792490053807584e-07
# Best-12(val acc:0.38) | lr:0.001676733428387392, weight decay:6.196202850187026e-08
# Best-13(val acc:0.34) | lr:0.003000261343567309, weight decay:7.726689232090652e-07
# Best-14(val acc:0.33) | lr:0.001525596258996269, weight decay:5.044617652141686e-08
# Best-15(val acc:0.32) | lr:0.0019401186812738195, weight decay:1.0767856048009218e-08
# Best-16(val acc:0.32) | lr:0.0010747572972545296, weight decay:1.8232479504070807e-08
# Best-17(val acc:0.31) | lr:0.002586946908303264, weight decay:8.259712738528455e-05
# Best-18(val acc:0.28) | lr:0.0013676246833997825, weight decay:6.636261820757041e-05
# Best-19(val acc:0.27) | lr:0.000637384191268236, weight decay:1.458050531833478e-08
# Best-20(val acc:0.26) | lr:0.002235417494841485, weight decay:7.60155058104173e-05
